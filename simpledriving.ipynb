# %% [markdown]
# <a href="https://colab.research.google.com/github/onurdas/simple-driving/blob/main/simpledriving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip simple-driving.zip
# Out:
# Archive:  simple-driving.zip
#    creating: simple-driving/
#   inflating: simple-driving/agent.pth
#   inflating: simple-driving/agent.py
#   inflating: simple-driving/example.py
#   inflating: simple-driving/README.md
#   inflating: simple-driving/setup.py
#    creating: simple-driving/simple_driving/
#    creating: simple-driving/simple_driving/envs/
#   inflating: simple-driving/simple_driving/envs/env2.py
#   inflating: simple-driving/simple_driving/envs/simple_driving_env.py
#   inflating: simple-driving/simple_driving/envs/__init__.py
#    creating: simple-driving/simple_driving/resources/
#   inflating: simple-driving/simple_driving/resources/car.py
#   inflating: simple-driving/simple_driving/resources/goal.py
#   inflating: simple-driving/simple_driving/resources/plane.py
#   inflating: simple-driving/simple_driving/resources/simplecar.urdf
#   inflating: simple-driving/simple_driving/resources/simplegoal.urdf
# ...

# %%
# %cd simple-driving
# Out:
# /content/simple-driving

# %%
# %pip install -e .
# Out:
# Obtaining file:///content/gym-examples
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.3/710.3 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 33.9 MB/s eta 0:00:00
# ...
#   Created wheel for gym: filename=gym-0.26.0-py3-none-any.whl size=826273 sha256=f35c71b11f4e0d18e3e6ec66432f3411d4421eb59b8a7645ae72d1fced287568
#   Stored in directory: /root/.cache/pip/wheels/cd/da/7c/a034980e59e34687bfb6cfa3a5f3e9b389264a0c59519c59fa
# Successfully built gym
# ...
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ...

# %%
import gymnasium
import simple_driving
import time
from numpngw import write_apng
from IPython.display import Image
env = gymnasium.make('SimpleDriving-v0', render_mode="human")
ob = env.reset()
images = [env.render()]

termination = False
truncation = False

while not termination or truncation:
    observation, reward, termination, truncation, info = env.step(env.action_space.sample())
    images.append(env.render())
    if termination or truncation:
      observation, info = env.reset()
      time.sleep(1/30)
      images.append(env.render())
env.close()
write_apng("anim.png", images, delay=40)  # real-time rendering = 40 ms between frames
Image(filename="anim.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:266: UserWarning: WARN: Human rendering should return `None`, got <class 'numpy.ndarray'>
#   logger.warn(

# %%
from gymnasium import envs
print(envs.registry.keys())
# Out:
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v2', 'LunarLanderContinuous-v2', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v2', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v0', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Pusher-v2', 'Pusher-v4', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'GymV21Environment-v0', 'GymV26Environment-v0'])
